# %%
from qiskit.transpiler import PassManager, InstructionDurations

# %%
import os
os.getcwd()
os.chdir('/home/siyuan/Seafile/Thesis/PycharmProjects/DD_PE_paper/')

# %%
from qiskit import IBMQ, transpile, Aer
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-france', group='univ-montpellier', project='default')
backend = provider.get_backend('ibmq_guadalupe')

# %%
from src.tools.DD_insertion import construct_bv_circuit, \
                                 construct_graph_matrix, \
                                 convert_count_to_prob, \
                                 translate_circuit_to_basis

# %%
from qiskit.circuit.library import QFT, GraphState

# %%
bv_circuits = []
hs_circuits = []
qft_circuits = []
for i in range(3, 15):
    bv_circuits.append(construct_bv_circuit(i))

# for i in range(2, 15, 2):
#     hs_circuits.append(construct_hs_circuit(i))

for i in range(3, 15):
    qft_circuits.append(QFT(i))

for circuit in bv_circuits:
    circuit.measure_all()

# for circuit in hs_circuits:
#     circuit.measure_all()

for circuit in qft_circuits:
    circuit.measure_all()

# %%
durations = InstructionDurations.from_backend(backend)
## add duration of y gates which are used for DD sequences
bconf = backend.configuration()
for i in range(bconf.num_qubits):
    x_duration = durations.get('x', i)
    durations.update(InstructionDurations(
        [('y', i, x_duration)]
        ))

    durations.update(InstructionDurations(
        [('rx', i, x_duration)]
        ))

    durations.update(InstructionDurations(
        [('ry', i, x_duration)]
        ))

# %%
graph_state_circuits = []
coupling_map = backend.configuration().coupling_map

for i in range(3, 15):
    gs_circuit_matrix = construct_graph_matrix(i, coupling_map)
    graph_state_circuits.append(GraphState(gs_circuit_matrix))

for circuit in graph_state_circuits:
    circuit.measure_all()

# %%
from src.tools.DD_insertion import pm_DD_sequences
pms = pm_DD_sequences(durations)

# %%
bv_job_ids = []
bv_jobs = []

for circuit in bv_circuits:
    circuit_list = []
    transpiled_qc = transpile(circuit, backend=backend, optimization_level=3, seed_transpiler=1)
    circuit_list.append(transpiled_qc)
    for pm in pms:
        qc_transpile = pm.run(transpiled_qc)
        qc_transpile_base = translate_circuit_to_basis(qc_transpile, bconf)
        circuit_list.append(qc_transpile_base)
    job = backend.run(circuit_list, shots=8192)
    bv_jobs.append(job)
    job_id = job.job_id()
    print(job_id)
    bv_job_ids.append(job_id)
# Out:
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# 628e1ed897dfca76ac1294a7
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1eda68f4d6633d83a75d
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1edc50f23d59d3cb5b02
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1edf5ca8b443945bf3d2
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ee2ef70696173791038
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ee5386b01d2ca1859a6
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ee85ca8b46dd15bf3d4
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1eec97dfca5f7c1294a8
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1eefef70694ec7791039
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ef3386b01d8c91859a9
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ef65ca8b42f615bf3d5
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ef9ef706987dc79103a

# %%
for job_id in bv_job_ids:
    print(job_id)
# Out:
# 628e1ed897dfca76ac1294a7
# 628e1eda68f4d6633d83a75d
# 628e1edc50f23d59d3cb5b02
# 628e1edf5ca8b443945bf3d2
# 628e1ee2ef70696173791038
# 628e1ee5386b01d2ca1859a6
# 628e1ee85ca8b46dd15bf3d4
# 628e1eec97dfca5f7c1294a8
# 628e1eefef70694ec7791039
# 628e1ef3386b01d8c91859a9
# 628e1ef65ca8b42f615bf3d5
# 628e1ef9ef706987dc79103a

# %%
from qiskit import execute

shots = 8192
psts = []
bv_job_ids = [
    '628e1ed897dfca76ac1294a7',
    '628e1eda68f4d6633d83a75d',
    '628e1edc50f23d59d3cb5b02',
    '628e1edf5ca8b443945bf3d2',
    '628e1ee2ef70696173791038',
    '628e1ee5386b01d2ca1859a6',
    '628e1ee85ca8b46dd15bf3d4',
    '628e1eec97dfca5f7c1294a8',
    '628e1eefef70694ec7791039',
    '628e1ef3386b01d8c91859a9',
    '628e1ef65ca8b42f615bf3d5',
    '628e1ef9ef706987dc79103a',

]
for i, circuit in enumerate(bv_circuits):
    ideal_counts = execute(circuit, backend=Aer.get_backend('qasm_simulator'), shots=shots).result().get_counts()
    ideal_result = list(ideal_counts.keys())[0]
    result_counts = backend.retrieve_job(bv_job_ids[i]).result().get_counts()
    pst = []
    for result_count in result_counts:
        pst.append(result_count[ideal_result]/shots)
    psts.append(pst)

bv_circuit_names = ['BV3', 'BV4', 'BV5', 'BV6', 'BV7', 'BV8', 'BV9', 'BV10', 'BV11', 'BV12', 'BV13', 'BV14']
DD_sequences = ['no_dd', 'hahn_X', 'hahn_Y', 'CP', 'CPMG', 'xy4', 'xy8', 'xy16', 'udd1', 'udd2', 'kdd']
bv_results_data = {}

for i, name in enumerate(bv_circuit_names):
    print(f'---------Result of circuit {name} -------------')
    for j, pst in enumerate(psts[i]):
        print(f'pst result of {DD_sequences[j]}: {pst}')
    bv_results_data[name] = psts[i]
# Out:
# ---------Result of circuit BV3 -------------
# pst result of no_dd: 0.4388427734375
# pst result of hahn_X: 0.43603515625
# pst result of hahn_Y: 0.4373779296875
# pst result of CP: 0.4554443359375
# pst result of CPMG: 0.448974609375
# pst result of xy4: 0.4674072265625
# pst result of xy8: 0.43896484375
# pst result of xy16: 0.4525146484375
# pst result of udd1: 0.4654541015625
# pst result of udd2: 0.423583984375
# pst result of kdd: 0.439208984375
# ---------Result of circuit BV4 -------------
# pst result of no_dd: 0.41015625
# pst result of hahn_X: 0.4130859375
# pst result of hahn_Y: 0.3992919921875
# pst result of CP: 0.4229736328125
# pst result of CPMG: 0.409423828125
# pst result of xy4: 0.4033203125
# pst result of xy8: 0.41162109375
# pst result of xy16: 0.4166259765625
# pst result of udd1: 0.41748046875
# pst result of udd2: 0.4119873046875
# pst result of kdd: 0.412109375
# ---------Result of circuit BV5 -------------
# pst result of no_dd: 0.1314697265625
# pst result of hahn_X: 0.1280517578125
# pst result of hahn_Y: 0.1348876953125
# pst result of CP: 0.241455078125
# pst result of CPMG: 0.255126953125
# pst result of xy4: 0.26611328125
# pst result of xy8: 0.235595703125
# pst result of xy16: 0.2227783203125
# pst result of udd1: 0.242431640625
# pst result of udd2: 0.2156982421875
# pst result of kdd: 0.21142578125
# ---------Result of circuit BV6 -------------
# pst result of no_dd: 0.1551513671875
# pst result of hahn_X: 0.1575927734375
# pst result of hahn_Y: 0.15087890625
# pst result of CP: 0.2593994140625
# pst result of CPMG: 0.2486572265625
# pst result of xy4: 0.27978515625
# pst result of xy8: 0.2752685546875
# pst result of udd2: 0.0723876953125
# pst result of kdd: 0.0506591796875
# ---------Result of circuit BV14 -------------
# pst result of no_dd: 0.0001220703125
# pst result of hahn_X: 0.00048828125
# pst result of hahn_Y: 0.000244140625
# pst result of CP: 0.01025390625
# pst result of CPMG: 0.0107421875
# pst result of xy4: 0.0078125
# pst result of xy8: 0.010986328125
# pst result of xy16: 0.018310546875
# pst result of udd1: 0.0128173828125
# pst result of udd2: 0.0042724609375
# pst result of kdd: 0.0225830078125

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# baseline = []
# data = []
# for name in bv_circuit_names:
#     result_data = bv_results_data[name]
#     baseline.append(result_data[0])
#     ratio = [i/result_data[0] for i in result_data[1:]]
#     data.append(ratio)


# data = np.array(data)

# # hahn_X = data[:, 0]
# # hahn_Y = data[:, 1]
# cp = data[1:, 2]
# cpmg = data[1:, 3]
# xy4 = data[1:, 4]
# xy8 = data[1:, 5]
# xy16 = list(data[2:, 6])
# xy16.insert(0, None)
# udd_X = data[1:, 7]
# udd_Y = data[1:, 8]
# kdd = list(data[2:, 9])
# kdd.insert(0, None)

# circuit_names = ['BV3', 'BV4', 'BV5', 'BV6', 'BV7', 'BV8', 'BV9', 'BV10', 'BV11', 'BV12',]

# x_ticks = circuit_names[:7]
# X = np.arange(len(x_ticks))

# from matplotlib.pyplot import figure
# fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
# ax = fig.add_axes([0,0,1,1])

# # plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# # plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
# plt.plot(X, cp[:-2][:7], linestyle='--', marker='o', color='orange', label='cp')
# plt.plot(X, cpmg[:-2][:7], linestyle='--', marker='.', color='b', label='cpmg')
# plt.plot(X, xy4[:-2][:7], linestyle='--', marker='^', color='r', label='xy4')
# plt.plot(X, xy8[:-2][:7], linestyle='--', marker='X', color='g', label='xy8')
# plt.plot(X, xy16[:-2][:7], linestyle='--', marker='h', color='c', label='xy16')
# plt.plot(X, udd_X[:-2][:7], linestyle='--', marker='d', color='y', label='udd_x')
# plt.plot(X, udd_Y[:-2][:7], linestyle='--', marker='+', color='k', label='udd_y')
# plt.plot(X, kdd[:-2][:7], linestyle='--', marker='*', color='m', label='kdd')

# plt.axhline(1, color='tab:brown', lw=2)

# plt.legend(loc='best', fontsize=16)
# # ax.set_title('Relative PST result for BV circuit on ibmq_guadalupe', fontsize=18)
# ax.set_xticks(X)
# ax.set_xticklabels(x_ticks, fontsize=14)
# ax.set_ylabel('Relative PST', fontsize=16)
# plt.savefig('TQE_Relat_PST_BV_guadalupe.pdf', bbox_inches='tight', pad_inches=0)

# %%
gs_job_ids = []
gs_jobs = []

for circuit in graph_state_circuits:
    circuit_list = []
    transpiled_qc = transpile(circuit, backend=backend, optimization_level=3, seed_transpiler=1)
    circuit_list.append(transpiled_qc)
    for pm in pms:
        qc_transpile = pm.run(transpiled_qc)
        qc_transpile_base = translate_circuit_to_basis(qc_transpile, bconf)
        circuit_list.append(qc_transpile_base)
    job = backend.run(circuit_list, shots=8192)
    gs_jobs.append(job)
    job_id = job.job_id()
    print(job_id)
    gs_job_ids.append(job_id)
# Out:
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f8b68f4d6131283a760
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f8def7069e38b79103d
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f8f4a0d3cf12a2180fb
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f91386b0167ed1859ac
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f9397dfca07e51294ac
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f95ef7069608b79103e
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f975ca8b497bd5bf3d8
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f9997dfcabd561294ad
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f9bef7069e576791040
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f9d50f23d9ca9cb5b07
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1f9f5ca8b47e255bf3d9
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fa268f4d64a5a83a761

# %%
for job_id in gs_job_ids:
    print(job_id)
# Out:
# 628e1f8b68f4d6131283a760
# 628e1f8def7069e38b79103d
# 628e1f8f4a0d3cf12a2180fb
# 628e1f91386b0167ed1859ac
# 628e1f9397dfca07e51294ac
# 628e1f95ef7069608b79103e
# 628e1f975ca8b497bd5bf3d8
# 628e1f9997dfcabd561294ad
# 628e1f9bef7069e576791040
# 628e1f9d50f23d9ca9cb5b07
# 628e1f9f5ca8b47e255bf3d9
# 628e1fa268f4d64a5a83a761

# %%
from scipy.spatial.distance import jensenshannon
from qiskit import execute
gs_jsds = []

gs_job_ids = [
    '628e1f8b68f4d6131283a760',
    '628e1f8def7069e38b79103d',
    '628e1f8f4a0d3cf12a2180fb',
    '628e1f91386b0167ed1859ac',
    '628e1f9397dfca07e51294ac',
    '628e1f95ef7069608b79103e',
    '628e1f975ca8b497bd5bf3d8',
    '628e1f9997dfcabd561294ad',
    '628e1f9bef7069e576791040',
    '628e1f9d50f23d9ca9cb5b07',
    '628e1f9f5ca8b47e255bf3d9',
    '628e1fa268f4d64a5a83a761',
]


shots = 8192

for i, circuit in enumerate(graph_state_circuits):
    ideal_counts = execute(circuit, backend=Aer.get_backend('qasm_simulator'), shots=shots).result().get_counts()
    result_counts = backend.retrieve_job(gs_job_ids[i]).result().get_counts()
    jsd = []
    for result_count in result_counts:
        p_ideal, p_result = convert_count_to_prob(result_count, ideal_counts, shots=shots)
        jsd.append(jensenshannon(p_ideal, p_result))
    gs_jsds.append(jsd)

circuit_names = ['GS3', 'GS4', 'GS5', 'GS6', 'GS7', 'GS8', 'GS9', 'GS10', 'GS11', 'GS12', 'GS13', 'GS14']
DD_sequences = ['no_dd', 'hahn_X', 'hahn_Y', 'CP', 'CPMG', 'xy4', 'xy8', 'xy16', 'udd1', 'udd2', 'kdd']

gs_results_data = {}

for i, name in enumerate(circuit_names):
    print(f'---------Result of circuit {name} -------------')
    for j, jsd in enumerate(gs_jsds[i]):
        print(f'jsd result of {DD_sequences[j]}: {jsd}')
    gs_results_data[name] = gs_jsds[i]
# Out:
# ---------Result of circuit GS3 -------------
# jsd result of no_dd: 0.1407971279566968
# jsd result of hahn_X: 0.14541703879784557
# jsd result of hahn_Y: 0.14498952748630836
# jsd result of CP: 0.034813356958314716
# jsd result of CPMG: 0.05325442657040355
# jsd result of xy4: 0.05193404417526117
# jsd result of xy8: 0.052992290127455384
# jsd result of xy16: 0.04155690758411767
# jsd result of udd1: 0.062413649133906235
# jsd result of hahn_X: 0.21873199004671892
# jsd result of hahn_Y: 0.2178246106142685
# jsd result of CP: 0.19799215260131758
# jsd result of CPMG: 0.21058576462910666
# jsd result of xy4: 0.20138421113329724
# jsd result of xy8: 0.18775931294171241
# jsd result of xy16: 0.18796725647241
# jsd result of udd1: 0.19061435158014947
# jsd result of udd2: 0.21033992814136587
# jsd result of kdd: 0.20455287124527596
# ---------Result of circuit GS11 -------------
# jsd result of no_dd: 0.28144137974432293
# jsd result of hahn_X: 0.28313174413228825
# jsd result of hahn_Y: 0.2854393506189369
# jsd result of CP: 0.27051145281867495
# jsd result of CPMG: 0.2641900784643058
# jsd result of xy4: 0.2590434078459606
# jsd result of xy8: 0.2586314517181456
# jsd result of xy16: 0.2582760105597728
# jsd result of udd1: 0.255421037556741
# jsd result of udd2: 0.2675937326856382
# jsd result of kdd: 0.27072328666271017
# ---------Result of circuit GS12 -------------
# jsd result of no_dd: 0.3420961962027848
# jsd result of hahn_X: 0.3412621358991439
# jsd result of hahn_Y: 0.3431160546405236
# jsd result of CP: 0.33897227133936636
# jsd result of CPMG: 0.34109546203616065
# jsd result of xy4: 0.33831234251258946
# jsd result of xy8: 0.3377689719940772
# jsd result of xy16: 0.3414313710433882
# jsd result of udd1: 0.33439563475000283
# jsd result of udd2: 0.3391212450522231
# jsd result of kdd: 0.3396258975791693
# ---------Result of circuit GS13 -------------
# jsd result of no_dd: 0.4346822362194862
# jsd result of hahn_X: 0.43860585504274413
# jsd result of hahn_Y: 0.4367979602506605
# jsd result of CP: 0.4303942640674327
# jsd result of CPMG: 0.43302973594103733
# jsd result of xy4: 0.43280975167459973
# jsd result of xy8: 0.4366366559839517
# jsd result of xy16: 0.4367732780030527
# jsd result of udd1: 0.43406947634304593
# jsd result of udd2: 0.43295087378991093
# jsd result of kdd: 0.4360438106272613
# ---------Result of circuit GS14 -------------
# jsd result of no_dd: 0.5449222135804993
# jsd result of hahn_X: 0.5454170432758729
# jsd result of hahn_Y: 0.5478286285885994
# jsd result of CP: 0.542167242122482
# jsd result of CPMG: 0.5474599490392534
# jsd result of xy4: 0.5414221461928502
# jsd result of xy8: 0.545167587525303
# jsd result of xy16: 0.5441902193871173
# jsd result of udd1: 0.5450699226003818
# jsd result of udd2: 0.5410062349946483
# jsd result of kdd: 0.5458459330774494

# %%
# baseline = []

# data = []
# for name in circuit_names:
#     result_data = gs_results_data[name]
#     baseline.append(result_data[0])
#     ratio = [result_data[0]/i for i in result_data[1:]]
#     data.append(ratio)


# data = np.array(data)

# # hahn_X = data[:, 0]
# # hahn_Y = data[:, 1]
# cp = data[:, 2]
# cpmg = data[:, 3]
# xy4 = data[:, 4]
# xy8 = data[:, 5]
# xy16 = data[:, 6]
# udd_X = data[:, 7]
# udd_Y = data[:, 8]
# kdd = data[:, 9]

# x_ticks = circuit_names[:-2]
# X = np.arange(len(x_ticks))

# from matplotlib.pyplot import figure
# fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
# ax = fig.add_axes([0,0,1,1])

# # plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# # plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
# plt.plot(X, cp[:-2], linestyle='--', marker='o', color='orange', label='cp')
# plt.plot(X, cpmg[:-2], linestyle='--', marker='.', color='b', label='cpmg')
# plt.plot(X, xy4[:-2], linestyle='--', marker='^', color='r', label='xy4')
# plt.plot(X, xy8[:-2], linestyle='--', marker='X', color='g', label='xy8')
# plt.plot(X, xy16[:-2], linestyle='--', marker='h', color='c', label='xy16')
# plt.plot(X, udd_X[:-2], linestyle='--', marker='d', color='y', label='udd_x')
# plt.plot(X, udd_Y[:-2], linestyle='--', marker='+', color='k', label='udd_y')
# plt.plot(X, kdd[:-2], linestyle='--', marker='*', color='m', label='kdd')
# plt.axhline(1, color='tab:brown', lw=2)
# plt.legend(loc='best', fontsize=16)
# # ax.set_title('Relative JSD result for GS circuit on ibmq_guadalupe', fontsize=18)
# ax.set_xticks(X)
# ax.set_xticklabels(x_ticks, fontsize=14)
# ax.set_ylabel('Relative JSD', fontsize=16)

# plt.savefig('TQE_Relat_JSD_GS_guadalupe_T.pdf', bbox_inches='tight', pad_inches=0)

# %%
qft_job_ids = []
qft_jobs = []

for circuit in qft_circuits:
    circuit_list = []
    transpiled_qc = transpile(circuit, backend=backend, optimization_level=3, seed_transpiler=1)
    circuit_list.append(transpiled_qc)
    for pm in pms:
        qc_transpile = pm.run(transpiled_qc)
        qc_transpile_base = translate_circuit_to_basis(qc_transpile, bconf)
        circuit_list.append(qc_transpile_base)
    job = backend.run(circuit_list, shots=8192)
    qft_jobs.append(job)
    job_id = job.job_id()
    print(job_id)
    qft_job_ids.append(job_id)
# Out:
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fd85ca8b435b45bf3db
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fdb386b0145771859af
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fde0814ba1970ddd248
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fe24a0d3c1fa02180fd
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fea68f4d6317a83a764
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1fef5ca8b4885e5bf3dc
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e1ff668f4d675a983a765
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e200050f23d802acb5b09
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e200a68f4d6229e83a766
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e201697dfca05bb1294af
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e2023d6a061fb842af840
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628e203150f23d4219cb5b0a

# %%
for job_id in qft_job_ids:
    print(job_id)
# Out:
# 628e1fd85ca8b435b45bf3db
# 628e1fdb386b0145771859af
# 628e1fde0814ba1970ddd248
# 628e1fe24a0d3c1fa02180fd
# 628e1fea68f4d6317a83a764
# 628e1fef5ca8b4885e5bf3dc
# 628e1ff668f4d675a983a765
# 628e200050f23d802acb5b09
# 628e200a68f4d6229e83a766
# 628e201697dfca05bb1294af
# 628e2023d6a061fb842af840
# 628e203150f23d4219cb5b0a

# %%
from scipy.spatial.distance import jensenshannon
qft_jsds = []

qft_job_ids = [
    '628e1fd85ca8b435b45bf3db',
    '628e1fdb386b0145771859af',
    '628e1fde0814ba1970ddd248',
    '628e1fe24a0d3c1fa02180fd',
    '628e1fea68f4d6317a83a764',
    '628e1fef5ca8b4885e5bf3dc',
    '628e1ff668f4d675a983a765',
    '628e200050f23d802acb5b09',
    '628e200a68f4d6229e83a766',
    '628e201697dfca05bb1294af',
    '628e2023d6a061fb842af840',
    '628e203150f23d4219cb5b0a'
]

shots = 8192

for i, circuit in enumerate(qft_circuits):
    ideal_counts = execute(circuit, backend=Aer.get_backend('qasm_simulator'), shots=shots).result().get_counts()
    result_counts = backend.retrieve_job(qft_job_ids[i]).result().get_counts()
    jsd = []
    for result_count in result_counts:
        p_ideal, p_result = convert_count_to_prob(result_count, ideal_counts, shots=shots)
        jsd.append(jensenshannon(p_ideal, p_result))
    qft_jsds.append(jsd)

circuit_names = ['QFT3', 'QFT4', 'QFT5', 'QFT6', 'QFT7', 'QFT8', 'QFT9', 'QFT10', 'QFT11', 'QFT12', 'QFT13', 'QFT14']
DD_sequences = ['no_dd', 'hahn_X', 'hahn_Y', 'CP', 'CPMG', 'xy4', 'xy8', 'xy16', 'udd1', 'udd2', 'kdd']

qft_results_data = {}

for i, name in enumerate(circuit_names):
    print(f'---------Result of circuit {name} -------------')
    for j, jsd in enumerate(qft_jsds[i]):
        print(f'jsd result of {DD_sequences[j]}: {jsd}')
    qft_results_data[name] = qft_jsds[i]
# Out:
# ---------Result of circuit QFT3 -------------
# jsd result of no_dd: 0.04891513837743728
# jsd result of hahn_X: 0.05061609821802133
# jsd result of hahn_Y: 0.043144315694877866
# jsd result of CP: 0.05195009160025009
# jsd result of CPMG: 0.056519189713500305
# jsd result of xy4: 0.07571541504192043
# jsd result of xy8: 0.06726749892898347
# jsd result of xy16: 0.05001153327524266
# jsd result of udd1: 0.043985745318517025
# jsd result of udd2: 0.10462040690680942
# jsd result of kdd: 0.06637105550021151
# ---------Result of circuit QFT4 -------------
# jsd result of no_dd: 0.04919023685045278
# jsd result of hahn_X: 0.06119314345108631
# jsd result of hahn_Y: 0.05842431684130809
# jsd result of CP: 0.05840261562121494
# jsd result of CPMG: 0.06323677266489272
# jsd result of xy4: 0.07095292310135111
# jsd result of xy8: 0.05414782030549029
# jsd result of xy16: 0.07370141813279679
# jsd result of udd1: 0.07261907517032709
# jsd result of udd2: 0.05115786161578287
# jsd result of kdd: 0.08847501585755038
# ---------Result of circuit QFT5 -------------
# jsd result of no_dd: 0.13655277891750067
# jsd result of hahn_X: 0.12637921235737995
# jsd result of hahn_Y: 0.1270507468375061
# jsd result of CP: 0.05389927159210886
# jsd result of CPMG: 0.06556512852885299
# jsd result of xy4: 0.07012030149854961
# jsd result of xy8: 0.07043177146216363
# jsd result of xy16: 0.06278384540385493
# jsd result of udd1: 0.061154404230928966
# jsd result of udd2: 0.08529171904361556
# jsd result of kdd: 0.06944397973623792
# ---------Result of circuit QFT6 -------------
# jsd result of no_dd: 0.0750250063069745
# jsd result of hahn_X: 0.08984089686538925
# jsd result of hahn_Y: 0.08941935368441874
# jsd result of CP: 0.08052155359984917
# jsd result of CPMG: 0.08561034927529912
# jsd result of xy4: 0.09007934179744119
# jsd result of xy8: 0.09136627601227228
# jsd result of xy16: 0.09049095394273471
# jsd result of udd1: 0.09259055388395473
# jsd result of udd2: 0.13432449702462199
# jsd result of kdd: 0.11254916157692503
# jsd result of CP: 0.4336883656341345
# jsd result of CPMG: 0.43438321262555846
# jsd result of xy4: 0.44264484906356183
# jsd result of xy8: 0.4411762398570086
# jsd result of xy16: 0.4391052002545663
# jsd result of udd1: 0.4364901036742781
# jsd result of udd2: 0.43693707907476825
# jsd result of kdd: 0.43573306173533344
# ---------Result of circuit QFT14 -------------
# jsd result of no_dd: 0.5586370902790587
# jsd result of hahn_X: 0.5554884793199479
# jsd result of hahn_Y: 0.5563761791438837
# jsd result of CP: 0.5472721623453034
# jsd result of CPMG: 0.5479664376949979
# jsd result of xy4: 0.5442383467364295
# jsd result of xy8: 0.5466079345392156
# jsd result of xy16: 0.5465964521931819
# jsd result of udd1: 0.5442948341671279
# jsd result of udd2: 0.5444424061163325
# jsd result of kdd: 0.5501598648219085

# %%
qft_results_data
# Out:
# {'QFT3': [0.04891513837743728,
#   0.05061609821802133,
#   0.043144315694877866,
#   0.05195009160025009,
#   0.056519189713500305,
#   0.07571541504192043,
#   0.06726749892898347,
#   0.05001153327524266,
#   0.043985745318517025,
#   0.10462040690680942,
#   0.06637105550021151],
#  'QFT4': [0.04919023685045278,
#   0.06119314345108631,
#   0.05842431684130809,
#   0.05840261562121494,
#   0.06323677266489272,
#   0.07095292310135111,
#   0.05414782030549029,
#   0.07370141813279679,
#   0.07261907517032709,
#   0.05115786161578287,
#   0.08847501585755038],
#  'QFT5': [0.13655277891750067,
#   0.12637921235737995,
#   0.1270507468375061,
#   0.05389927159210886,
#   0.06556512852885299,
#   0.07012030149854961,
#   0.07043177146216363,
#   0.06278384540385493,
#   0.061154404230928966,
#   0.08529171904361556,
#   0.06944397973623792],
#  'QFT6': [0.0750250063069745,
#   0.08984089686538925,
#   0.08941935368441874,
#   0.08052155359984917,
#   0.08561034927529912,
#   0.09007934179744119,
#   0.09136627601227228,
#   0.09049095394273471,
#   0.09259055388395473,
#   0.13432449702462199,
#   0.11254916157692503],
#  'QFT7': [0.13143887613944336,
#   0.13979830584490505,
#   0.1360700156431868,
#   0.12123189636354346,
#   0.09334943799713824,
#   0.10148105195410022,
#   0.11769514705772856,
#   0.10717155019975101,
#   0.13299742172735335,
#   0.11932183907289308,
#   0.09549645464325207],
#  'QFT8': [0.12477964016103063,
#   0.1174489512717497,
#   0.12652752511170115,
#   0.13886430765178656,
#   0.13940279635496047,
#   0.15150139473154117,
#   0.14259584500214556,
#   0.12951123952059074,
#   0.13474417711426664,
#   0.15957210937861996,
#   0.11266710910415849],
#  'QFT9': [0.20755052654081335,
#   0.20026539504362828,
#   0.207134650613225,
#   0.18844787782828773,
#   0.1761163530855231,
#   0.16451642789363702,
#   0.17021275407619632,
#   0.15727837556111773,
#   0.19534086141104723,
#   0.19276926543048112,
#   0.15788244142234242],
#  'QFT10': [0.30963721956727946,
#   0.3098602935433507,
#   0.31360826510419604,
#   0.19002960480041092,
#   0.1859807584947951,
#   0.1923894835249772,
#   0.1969776807574257,
#   0.19647450537517153,
#   0.20012092640062304,
#   0.19622711905103002,
#   0.1921831305233527],
#  'QFT11': [0.2954739232150481,
#   0.2987106003139783,
#   0.2983381339055106,
#   0.2725631281468073,
#   0.270114750884156,
#   0.27337672497572346,
#   0.2719802441854886,
#   0.2614929677443405,
#   0.2742511733647403,
#   0.26786305200080884,
#   0.2555769652208908],
#  'QFT12': [0.37137781758771893,
#   0.36849112357178115,
#   0.3709817738327835,
#   0.33941000504714797,
#   0.3348545209611668,
#   0.3387115131164423,
#   0.3356876202879914,
#   0.3338584827015736,
#   0.3356897143682173,
#   0.333750103134894,
#   0.33529633662539066],
#  'QFT13': [0.4468547050717536,
#   0.44622590093266473,
#   0.44697888748608966,
#   0.4336883656341345,
#   0.43438321262555846,
#   0.44264484906356183,
#   0.4411762398570086,
#   0.4391052002545663,
#   0.4364901036742781,
#   0.43693707907476825,
#   0.43573306173533344],
#  'QFT14': [0.5586370902790587,
#   0.5554884793199479,
#   0.5563761791438837,
#   0.5472721623453034,
#   0.5479664376949979,
#   0.5442383467364295,
#   0.5466079345392156,
#   0.5465964521931819,
#   0.5442948341671279,
#   0.5444424061163325,
#   0.5501598648219085]}

# %%
# import matplotlib.pyplot as plt
# baseline = []

# data = []
# for name in circuit_names:
#     result_data = qft_results_data[name]
#     baseline.append(result_data[0])
#     ratio = [result_data[0]/i for i in result_data[1:]]
#     data.append(ratio)


# data = np.array(data)

# # hahn_X = data[:, 0]
# # hahn_Y = data[:, 1]
# cp = data[:, 2]
# cpmg = data[:, 3]
# xy4 = data[:, 4]
# xy8 = data[:, 5]
# xy16 = data[:, 6]
# udd_X = data[:, 7]
# udd_Y = data[:, 8]
# kdd = data[:, 9]

# x_ticks = circuit_names[:-2]
# X = np.arange(len(x_ticks))

# from matplotlib.pyplot import figure
# fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
# ax = fig.add_axes([0,0,1,1])

# # plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# # plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
# plt.plot(X, cp[:-2], linestyle='--', marker='o', color='orange', label='cp')
# plt.plot(X, cpmg[:-2], linestyle='--', marker='.', color='b', label='cpmg')
# plt.plot(X, xy4[:-2], linestyle='--', marker='^', color='r', label='xy4')
# plt.plot(X, xy8[:-2], linestyle='--', marker='X', color='g', label='xy8')
# plt.plot(X, xy16[:-2], linestyle='--', marker='h', color='c', label='xy16')
# plt.plot(X, udd_X[:-2], linestyle='--', marker='d', color='y', label='udd_x')
# plt.plot(X, udd_Y[:-2], linestyle='--', marker='+', color='k', label='udd_y')
# plt.plot(X, kdd[:-2], linestyle='--', marker='*', color='m', label='kdd')
# plt.axhline(1, color='tab:brown', lw=2)
# plt.legend(loc='best', fontsize=16)
# # ax.set_title('Relative JSD result for QFT circuit on ibmq_guadalupe', fontsize=18)
# ax.set_xticks(X)
# ax.set_xticklabels(x_ticks, fontsize=14)
# ax.set_ylabel('Relative JSD', fontsize=16)

# plt.savefig('TQE_Relat_JSD_QFT_guadalupe.pdf', bbox_inches='tight', pad_inches=0)
