  0.412353515625,
  0.4200439453125,
  0.409912109375,
  0.3961181640625],
 'BV5': [0.218505859375,
  0.22705078125,
  0.2197265625,
  0.25146484375,
  0.255126953125,
  0.25732421875,
  0.251708984375,
  0.239990234375,
  0.260986328125,
  0.246826171875,
  0.230224609375],
 'BV6': [0.2200927734375,
  0.221435546875,
  0.231689453125,
  0.263916015625,
  0.2691650390625,
  0.2623291015625,
  0.24755859375,
  0.224853515625,
  0.252685546875,
  0.2564697265625,
  0.22216796875],
 'BV7': [0.0986328125,
  0.1019287109375,
  0.100341796875,
  0.2320556640625,
  0.220458984375,
  0.2203369140625,
  0.22216796875,
  0.196533203125,
  0.2420654296875,
  0.1893310546875,
  0.1661376953125],
 'BV8': [0.0731201171875,
  0.0711669921875,
  0.070556640625,
  0.190185546875,
  0.1763916015625,
  0.2283935546875,
  0.2166748046875,
  0.189697265625,
  0.2357177734375,
  0.2037353515625,
  0.1763916015625],
 'BV9': [0.0396728515625,
  0.0413818359375,
  0.044189453125,
  0.097412109375,
  0.08447265625,
  0.0797119140625,
  0.0770263671875,
  0.0802001953125,
  0.1038818359375,
  0.073486328125,
  0.0577392578125],
 'BV10': [0.0123291015625,
  0.011474609375,
  0.01220703125,
  0.076171875,
  0.0780029296875,
  0.09326171875,
  0.10107421875,
  0.0875244140625,
  0.0989990234375,
  0.0865478515625,
  0.0709228515625],
 'BV11': [0.0205078125,
  0.01708984375,
  0.0184326171875,
  0.0968017578125,
  0.0941162109375,
  0.10107421875,
  0.1011962890625,
  0.0762939453125,
  0.1038818359375,
  0.0933837890625,
  0.067626953125],
 'BV12': [0.002685546875,
  0.0010986328125,
  0.002685546875,
  0.036865234375,
  0.026611328125,
  0.035400390625,
  0.0419921875,
  0.0390625,
  0.0367431640625,
  0.0369873046875,
  0.030029296875],
 'BV13': [0.0081787109375,
  0.0087890625,
  0.009033203125,
  0.0313720703125,
  0.027587890625,
  0.037841796875,
  0.0467529296875,
  0.0418701171875,
  0.038818359375,
  0.040771484375,
  0.0379638671875],
 'BV14': [0.0069580078125,
  0.0062255859375,
  0.007080078125,
  0.0089111328125,
  0.0072021484375,
  0.010498046875,
  0.0311279296875,
  0.028564453125,
  0.03515625,
  0.02294921875,
  0.0228271484375]}

# %%
bv_circuit_names = ['BV4', 'BV5', 'BV6', 'BV7', 'BV8']
bv_results_data_avg = {}
bv_results_data = [bv_results_data1, bv_results_data2, bv_results_data3]
num = 11 #number of PSTs for one job

for circuit_name in bv_circuit_names:
    psts = []
    bv_results_data_avg[circuit_name] = []
    for i in range(num):
        avg = sum([bv_res[circuit_name][i] for bv_res in bv_results_data]) / 3
        bv_results_data_avg[circuit_name].append(avg)

# %%
import numpy as np
import matplotlib.pyplot as plt

baseline = []
bv_data = []
for name in bv_circuit_names:
    result_data = bv_results_data_avg[name]
    baseline.append(result_data[0])
    ratio = [i/result_data[0] for i in result_data[1:]]
    bv_data.append(ratio)

# %%
bv_data
# Out:
# [[0.9955680902497984,
#   1.0002014504431909,
#   1.0299153908138599,
#   1.015914585012087,
#   0.9851933924254633,
#   1.0022159548751006,
#   0.9864020950846092,
#   1.0096696212731668,
#   0.9870064464141821,
#   0.9486301369863014],
#  [1.0223763705526963,
#   1.0085030208100245,
#   1.6272096665920788,
#   1.6330275229357796,
#   1.6865070485567242,
#   1.620049228015216,
#   1.6095323338554484,
#   1.6216155739539044,
#   1.5829044528977398,
#   1.5723875587379728],
#  [1.0281339031339032,
#   1.0400641025641026,
#   1.2612179487179487,
#   1.2519586894586894,
#   1.2601495726495726,
#   1.2380698005698005,
#   1.126602564102564,
#   1.2225783475783476,
#   1.1839387464387465,
#   1.1178774928774928],
#  [1.0251317389541954,
#   1.0032428050263478,
#   2.489663558978516,
#   2.401297122010539,
#   2.426834211593028,
#   2.505877584110255,
#   2.2630725577624644,
#   2.443048236724767,
#   2.295095257397649,
#   2.09687880016214],
#  [0.9904168663152851,
#   0.9702922855773839,
#   2.04168663152851,
#   1.8763775754671776,
#   2.399137517968376,
#   2.3435553425970292,
#   2.1983708672735984,
#   2.560134163871586,
#   2.2903689506468616,
#   1.990896022999521]]

# %%
bv_data = np.array(bv_data)

# hahn_X = data[:, 0]
# hahn_Y = data[:, 1]
cp = bv_data[:, 2]
cpmg = bv_data[:, 3]
xy4 = bv_data[:, 4]
xy8 = bv_data[:, 5]
xy16 = bv_data[:, 6]
udd_X = bv_data[:, 7]
udd_Y = bv_data[:, 8]
kdd = bv_data[:, 9]


x_ticks = bv_circuit_names
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

# plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
plt.plot(X, cp, linestyle='--', marker='o', color='orange', label='cp')
plt.plot(X, cpmg, linestyle='--', marker='.', color='b', label='cpmg')
plt.plot(X, xy4, linestyle='--', marker='^', color='r', label='xy4')
plt.plot(X, xy8, linestyle='--', marker='X', color='g', label='xy8')
plt.plot(X, xy16, linestyle='--', marker='h', color='c', label='xy16')
plt.plot(X, udd_X, linestyle='--', marker='d', color='y', label='udd_x')
plt.plot(X, udd_Y, linestyle='--', marker='+', color='k', label='udd_y')
plt.plot(X, kdd, linestyle='--', marker='*', color='m', label='kdd')

plt.axhline(1, color='tab:brown', lw=2)

plt.legend(loc='best', fontsize=16)
# ax.set_title('Relative PST result for BV circuit on ibmq_guadalupe', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks, fontsize=14)
ax.set_ylabel('Relative PST', fontsize=16)
plt.savefig('TQE_Relat_PST_BV_montreal_avg.pdf', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Aerage of Graph State relative results on IBM Q 27 Montreal

  0.4369398185767922,
  0.4379237754033063,
  0.43840027121469566,
  0.4414134189237996,
  0.4399094758634506,
  0.4390251693113655,
  0.43611418350464626,
  0.4367179218015651,
  0.4347872732499581,
  0.4393019174382924],
 'GS14': [0.5482594809850019,
  0.5517377777417308,
  0.5472828086763413,
  0.5453343494521218,
  0.548975303503251,
  0.5459849305799376,
  0.5425865702877731,
  0.5486199197397661,
  0.5478134514743372,
  0.5431182498448679,
  0.5438757346614843]}

# %%
gs_circuit_names = ['GS4', 'GS5', 'GS6', 'GS7', 'GS8', 'GS9', 'GS10', 'GS11', 'GS12']
gs_results_data_avg = {}
gs_results_data = [gs_results_data1, gs_results_data2, gs_results_data3]
num = 11 #number of PSTs for one job

for circuit_name in gs_circuit_names:
    psts = []
    gs_results_data_avg[circuit_name] = []
    for i in range(num):
        avg = sum([gs_res[circuit_name][i] for gs_res in gs_results_data]) / 3
        gs_results_data_avg[circuit_name].append(avg)

# %%
baseline = []

gs_data = []
for name in gs_circuit_names:
    result_data = gs_results_data_avg[name]
    baseline.append(result_data[0])
    ratio = [result_data[0]/i for i in result_data[1:]]
    gs_data.append(ratio)


gs_data = np.array(gs_data)

# hahn_X = gs_data[:, 0]
# hahn_Y = gs_data[:, 1]
cp = gs_data[:, 2]
cpmg = gs_data[:, 3]
xy4 = gs_data[:, 4]
xy8 = gs_data[:, 5]
xy16 = gs_data[:, 6]
udd_X = gs_data[:, 7]
udd_Y = gs_data[:, 8]
kdd = gs_data[:, 9]

x_ticks = gs_circuit_names
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

# plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
plt.plot(X, cp, linestyle='--', marker='o', color='orange', label='cp')
plt.plot(X, cpmg, linestyle='--', marker='.', color='b', label='cpmg')
plt.plot(X, xy4, linestyle='--', marker='^', color='r', label='xy4')
plt.plot(X, xy8, linestyle='--', marker='X', color='g', label='xy8')
plt.plot(X, xy16, linestyle='--', marker='h', color='c', label='xy16')
plt.plot(X, udd_X, linestyle='--', marker='d', color='y', label='udd_x')
plt.plot(X, udd_Y, linestyle='--', marker='+', color='k', label='udd_y')
plt.plot(X, kdd, linestyle='--', marker='*', color='m', label='kdd')
plt.axhline(1, color='tab:brown', lw=2)
plt.legend(loc='best', fontsize=16)
# ax.set_title('Relative JSD result for GS circuit on ibmq_guadalupe', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks, fontsize=14)
ax.set_ylabel('Relative JSD', fontsize=16)

plt.savefig('TQE_Relat_JSD_GS_montreal_avg.pdf', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## Aerage of QFT relative results on IBM Q 27 Montreal

  0.3425152339244638],
 'QFT13': [0.45978633243449557,
  0.4609785850197921,
  0.45773406188634735,
  0.443404580308092,
  0.43587601929103753,
  0.43444650107085825,
  0.4394013384568014,
  0.4406237399302011,
  0.43531148327502656,
  0.4312409464371673,
  0.43290404811976646],
 'QFT14': [0.5442567550307161,
  0.5502232662332631,
  0.5472015526244653,
  0.5484841685216812,
  0.5456611158814132,
  0.5500823702869371,
  0.5408529761575567,
  0.546692474876133,
  0.5469726451309338,
  0.548702910530456,
  0.5510625071337957]}

# %%
qft_circuit_names = ['QFT4', 'QFT5', 'QFT6', 'QFT7', 'QFT8', 'QFT9', 'QFT10', 'QFT11', 'QFT12']
qft_results_data_avg = {}
qft_results_data = [qft_results_data1, qft_results_data2, qft_results_data3]
num = 11 #number of PSTs for one job

for circuit_name in qft_circuit_names:
    psts = []
    qft_results_data_avg[circuit_name] = []
    for i in range(num):
        avg = sum([qft_res[circuit_name][i] for qft_res in qft_results_data]) / 3
        qft_results_data_avg[circuit_name].append(avg)

# %%
import matplotlib.pyplot as plt
baseline = []

qft_data = []
for name in qft_circuit_names:
    result_data = qft_results_data_avg[name]
    baseline.append(result_data[0])
    ratio = [result_data[0]/i for i in result_data[1:]]
    qft_data.append(ratio)


qft_data = np.array(qft_data)

# hahn_X = data[:, 0]
# hahn_Y = data[:, 1]
cp = qft_data[:, 2]
cpmg = qft_data[:, 3]
xy4 = qft_data[:, 4]
xy8 = qft_data[:, 5]
xy16 = qft_data[:, 6]
udd_X = qft_data[:, 7]
udd_Y = qft_data[:, 8]
kdd = qft_data[:, 9]

x_ticks = qft_circuit_names
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

# plt.plot(X, hahn_Y, linestyle='--', marker='o', color='g', label='hahn_X')
# plt.plot(X, hahn_X, linestyle='--', marker='s', color='m', label='hahn_Y')
plt.plot(X, cp, linestyle='--', marker='o', color='orange', label='cp')
plt.plot(X, cpmg, linestyle='--', marker='.', color='b', label='cpmg')
plt.plot(X, xy4, linestyle='--', marker='^', color='r', label='xy4')
plt.plot(X, xy8, linestyle='--', marker='X', color='g', label='xy8')
plt.plot(X, xy16, linestyle='--', marker='h', color='c', label='xy16')
plt.plot(X, udd_X, linestyle='--', marker='d', color='y', label='udd_x')
plt.plot(X, udd_Y, linestyle='--', marker='+', color='k', label='udd_y')
plt.plot(X, kdd, linestyle='--', marker='*', color='m', label='kdd')
plt.axhline(1, color='tab:brown', lw=2)
plt.legend(loc='best', fontsize=16)
# ax.set_title('Relative JSD result for QFT circuit on ibmq_guadalupe', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks, fontsize=14)
ax.set_ylabel('Relative JSD', fontsize=16)

plt.savefig('TQE_Relat_JSD_QFT_montreal_avg.pdf', bbox_inches='tight', pad_inches=0)
