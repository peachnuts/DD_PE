# %% [markdown]
# # QAOA results on IBM Q 7 Jarkata

# %% [markdown]
# ## Exp-1 22/05/20

# %%
result_data1 = {'3-regular-4': [0.42431640625, 0.431396484375, 0.4107666015625, 0.50390625, 0.516357421875, 0.501220703125, 0.49755859375, 0.4864501953125, 0.507568359375, 0.4893798828125, 0.4808349609375, 0.5302734375, 0.508544921875, 0.526611328125, 0.5118408203125, 0.4993896484375, 0.505859375, 0.5081787109375, 0.4888916015625, 0.5189208984375, 0.511962890625, 0.4661865234375], '3-regular-6': [0.2296875, 0.220849609375, 0.216162109375, 0.355908203125, 0.34765625, 0.339892578125, 0.3294921875, 0.343603515625, 0.354443359375, 0.35869140625, 0.290478515625, 0.340576171875, 0.33974609375, 0.339306640625, 0.34482421875, 0.360400390625, 0.361962890625, 0.34189453125, 0.3728515625, 0.3421875, 0.3330078125, 0.378173828125], 'rand-4-0.5': [0.0360107421875, 0.0198974609375, 0.027587890625, 0.0321044921875, 0.027587890625, 0.0009765625, -0.022705078125, -0.0057373046875, 0.0518798828125, -0.0306396484375, -0.07421875, 0.0352783203125, 0.0224609375, 0.0360107421875, -0.01513671875, -0.008056640625, -0.0062255859375, 0.028076171875, 0.0025634765625, 0.010986328125, -0.0157470703125, -0.01513671875], 'rand-6-0.5': [0.06689453125, 0.059122721354166664, 0.06791178385416667, 0.19449869791666666, 0.1851806640625, 0.1822509765625, 0.22029622395833334, 0.19417317708333334, 0.19767252604166666, 0.19490559895833334, 0.18587239583333334, 0.21244303385416666, 0.20060221354166666, 0.20829264322916666, 0.24092610677083334, 0.2215576171875, 0.22440592447916666, 0.19205729166666666, 0.19185384114583334, 0.22591145833333334, 0.191162109375, 0.17036946614583334]}

# %% [markdown]
# ## Exp-2 22/05/30

# %%
result_data2 ={'3-regular-4': [0.32666015625, 0.3060302734375, 0.302734375, 0.4727783203125, 0.4573974609375, 0.44873046875, 0.4786376953125, 0.4619140625, 0.4954833984375, 0.425537109375, 0.369873046875, 0.503662109375, 0.5225830078125, 0.49267578125, 0.5478515625, 0.52001953125, 0.510986328125, 0.51904296875, 0.524169921875, 0.5498046875, 0.51708984375, 0.5042724609375], '3-regular-6': [0.356982421875, 0.366552734375, 0.3611328125, 0.385498046875, 0.383837890625, 0.37646484375, 0.372119140625, 0.353125, 0.39541015625, 0.370263671875, 0.345654296875, 0.424658203125, 0.43505859375, 0.4423828125, 0.422216796875, 0.408544921875, 0.414111328125, 0.414111328125, 0.392822265625, 0.418603515625, 0.398828125, 0.395556640625], 'rand-4-0.5': [0.04248046875, 0.0469970703125, 0.0262451171875, 0.061279296875, 0.08154296875, 0.0960693359375, 0.1319580078125, 0.0743408203125, 0.0654296875, 0.058349609375, 0.050537109375, 0.05224609375, 0.0401611328125, 0.0635986328125, 0.0740966796875, -0.021484375, -0.027099609375, 0.072021484375, 0.0975341796875, 0.0872802734375, 0.0916748046875, -0.037841796875], 'rand-6-0.5': [0.15787760416666666, 0.16166178385416666, 0.16158040364583334, 0.2600504557291667, 0.2664794921875, 0.24259440104166666, 0.2564697265625, 0.22574869791666666, 0.2641194661458333, 0.2575276692708333, 0.2156982421875, 0.22648111979166666, 0.22481282552083334, 0.22367350260416666, 0.2725830078125, 0.2727864583333333, 0.2764485677083333, 0.256591796875, 0.2642008463541667, 0.271728515625, 0.2760823567708333, 0.2555338541666667]}

# %% [markdown]
# ## Exp-1 22/06/01

# %%
result_data3 ={'3-regular-4': [0.3560791015625, 0.323974609375, 0.33984375, 0.5341796875, 0.511474609375, 0.5250244140625, 0.49853515625, 0.4869384765625, 0.5362548828125, 0.47509765625, 0.3857421875, 0.5440673828125, 0.5283203125, 0.5494384765625, 0.556884765625, 0.5772705078125, 0.5675048828125, 0.5712890625, 0.5494384765625, 0.5731201171875, 0.5594482421875, 0.533935546875], '3-regular-6': [0.3580078125, 0.360546875, 0.364453125, 0.3810546875, 0.367578125, 0.3546875, 0.371533203125, 0.36650390625, 0.380224609375, 0.373876953125, 0.34111328125, 0.45322265625, 0.439306640625, 0.440625, 0.428125, 0.4236328125, 0.421875, 0.412353515625, 0.3990234375, 0.428564453125, 0.405029296875, 0.41396484375], 'rand-4-0.5': [0.03466796875, 0.0526123046875, 0.04296875, 0.05908203125, 0.0986328125, 0.1019287109375, 0.111083984375, 0.067626953125, 0.08154296875, 0.0792236328125, 0.041259765625, 0.0716552734375, 0.0831298828125, 0.07177734375, 0.0947265625, -0.0108642578125, -0.0233154296875, 0.0732421875, 0.08056640625, 0.1002197265625, 0.0662841796875, -0.0321044921875], 'rand-6-0.5': [0.176513671875, 0.17854817708333334, 0.18212890625, 0.2718505859375, 0.2840983072916667, 0.2622477213541667, 0.2683512369791667, 0.24141438802083334, 0.2739664713541667, 0.27734375, 0.21573893229166666, 0.242431640625, 0.23445638020833334, 0.23453776041666666, 0.2774251302083333, 0.2790120442708333, 0.2848714192708333, 0.2714029947916667, 0.2690836588541667, 0.2818603515625, 0.2837727864583333, 0.25439453125]}

# %%
graph_name = ['3-regular-4', '3-regular-6',
              'rand-4-0.5', 'rand-6-0.5',]
results_data_avg = {}

results_data = [result_data1, result_data2, result_data3]
num = 22 #number of PSTs for one job

for circuit_name in graph_name:
    ars = []
    results_data_avg[circuit_name] = []
    for i in range(num):
        avg = sum([qaoa_res[circuit_name][i] for qaoa_res in results_data]) / 3
        results_data_avg[circuit_name].append(avg)

# %%
results_data_avg
# Out:
# {'3-regular-4': [0.3690185546875,
#   0.3538004557291667,
#   0.3511149088541667,
#   0.5036214192708334,
#   0.4950764973958333,
#   0.4916585286458333,
#   0.4915771484375,
#   0.4784342447916667,
#   0.5131022135416666,
#   0.4633382161458333,
#   0.4121500651041667,
#   0.5260009765625,
#   0.5198160807291666,
#   0.5229085286458334,
#   0.5388590494791666,
#   0.5322265625,
#   0.5281168619791666,
#   0.5328369140625,
#   0.5208333333333334,
#   0.5472819010416666,
#   0.5295003255208334,
#   0.50146484375],
#  '3-regular-6': [0.314892578125,
#   0.31598307291666666,
#   0.313916015625,
#   0.3741536458333334,
#   0.3663574218749999,
#   0.3570149739583333,
#   0.35771484375,
#   0.3544108072916667,
#   0.3766927083333333,
#   0.3676106770833334,
#   0.32574869791666666,
#   0.40615234375000003,
#   0.4047037760416667,
#   0.4074381510416667,
#   0.398388671875,
#   0.39752604166666666,
#   0.39931640625000003,
#   0.389453125,
#   0.388232421875,
#   0.3964518229166667,
# ...

# %%
baseline = []
import numpy as np
import matplotlib.pyplot as plt
# name = ['Baseline', 'cp', 'cpmgl', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',
#         'PE', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']

data = []
for name in graph_name:
    result_data = results_data_avg[name]
    baseline.append(result_data[0])
    ratio = [i - result_data[0] for i in result_data[1:]]
    data.append(ratio)


data = np.array(data)
# hahn = data[:, 0]
cp = data[:, 2]
cpmg = data[:, 3]
xy4 = data[:, 4]
xy8 = data[:, 5]
xy16 = data[:, 6]
udd_X = data[:, 7]
udd_Y = data[:, 8]
kdd = data[:, 9]

pe = data[:, 10]
# hahn_to = data[:, 10]
cp_pe = data[:, 13]
cpmg_pe = data[:, 14]
xy4_pe = data[:, 15]
xy8_pe = data[:, 16]
xy16_pe = data[:, 17]
udd_X_pe = data[:, 18]
udd_Y_pe = data[:, 19]
kdd_pe = data[:, 20]
graph_name_x = ['3-reg-4', '3-reg-6',
              'rand-4-0.5', 'rand-6-0.5',]
x_ticks = graph_name_x
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

# plt.plot(X, hahn, linestyle='--', marker='o', color='g', label='hahn')
plt.scatter(X, cp, s=50, marker='o', color='orange', label='cp')
plt.scatter(X, cpmg, s=50, marker='.', color='b', label='cpmg')
plt.scatter(X, xy4, s=50, marker='^', color='r', label='xy4')
plt.scatter(X, xy8, s=50, marker='X', color='g', label='xy8')
plt.scatter(X, xy16, s=50, marker='h', color='c', label='xy16')
plt.scatter(X, udd_X, s=50, marker='d', color='y', label='udd_x')
plt.scatter(X, udd_Y, s=50, marker='+', color='k', label='udd_y')
plt.scatter(X, kdd, s=50, marker='*', color='m', label='kdd')
# plt.plot(X, pe, linestyle='--', marker='>', color='c', label='pe')
# # plt.plot(X, hahn_to, linestyle='--', marker='s', color='m', label='hahn_to')
# plt.plot(X, cp_pe, linestyle='--', marker='P', color='tab:pink', label='cp_pe')
# plt.plot(X, cpmg_pe, linestyle='--', marker='h', color='tab:gray', label='cpmg_pe')
# plt.plot(X, xy4_pe, linestyle='--', marker='_', color='tab:purple', label='xy4_pe')
# plt.plot(X, xy8_pe, linestyle='--', marker='<', color='tab:cyan', label='xy8_pe')
# plt.plot(X, xy16_pe, linestyle='--', marker='8', color='lightgreen', label='xy16_pe')
# plt.plot(X, udd_X_pe, linestyle='--', marker='|', color='tab:brown', label='udd_x_pe')
# plt.plot(X, udd_Y_pe, linestyle='--', marker='X', color='tab:olive', label='udd_y_pe')
# plt.plot(X, kdd_pe, linestyle='--', marker='D', color='maroon', label='kdd_pe')

plt.axhline(0, color='tab:brown', lw=2)

plt.legend(loc='best', fontsize=14)
# ax.set_title('Relative approximate ratio with only DD sequences on ibmq_jakarta', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks)
ax.set_ylabel('Relative approximation ratio', fontsize=16)

plt.savefig('Relat_AR_jakarta_DD_avg.pdf', bbox_inches='tight', pad_inches=0)

# %%
baseline = []

# name = ['Baseline', 'cp', 'cpmgl', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',
#         'PE', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']

data = []
for name in graph_name:
    result_data = results_data_avg[name]
    baseline.append(result_data[0])
    ratio = [i - result_data[0] for i in result_data[1:]]
    data.append(ratio)


data = np.array(data)
# hahn = data[:, 0]
cp = data[:, 2]
cpmg = data[:, 3]
xy4 = data[:, 4]
xy8 = data[:, 5]
xy16 = data[:, 6]
udd_X = data[:, 7]
udd_Y = data[:, 8]
kdd = data[:, 9]

pe = data[:, 10]
# hahn_to = data[:, 10]
cp_pe = data[:, 13]
cpmg_pe = data[:, 14]
xy4_pe = data[:, 15]
xy8_pe = data[:, 16]
xy16_pe = data[:, 17]
udd_X_pe = data[:, 18]
udd_Y_pe = data[:, 19]
kdd_pe = data[:, 20]

x_ticks = graph_name_x
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

plt.scatter(X, pe, s=50, marker='P', color='tab:purple', label='pe')
# plt.plot(X, hahn_to, linestyle='--', marker='s', color='m', label='hahn_to')
plt.scatter(X, cp_pe, s=50, marker='o', color='orange', label='cp_pe')
plt.scatter(X, cpmg_pe, s=50, marker='.', color='b', label='cpmg_pe')
plt.scatter(X, xy4_pe, s=50, marker='^', color='r', label='xy4_pe')
plt.scatter(X, xy8_pe, s=50, marker='X', color='g', label='xy8_pe')
plt.scatter(X, xy16_pe, s=50, marker='h', color='c', label='xy16_pe')
plt.scatter(X, udd_X_pe, s=50, marker='d', color='y', label='udd_x_pe')
plt.scatter(X, udd_Y_pe, s=50, marker='+', color='k', label='udd_y_pe')
plt.scatter(X, kdd_pe, s=50, marker='*', color='m', label='kdd_pe')

plt.axhline(0, color='tab:brown', lw=2)

plt.legend(loc='best', fontsize=14)
# ax.set_title('Relative approximate ratio with DD sequences+pulse efficient on ibmq_jakarta', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks)
ax.set_ylabel('Relative approximation ratio', fontsize=16)

plt.savefig('Relat_AR_jakarta_DD_pe_avg.pdf', bbox_inches='tight', pad_inches=0)

# %%
name = ['cp', 'cpmg', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',
'PE', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']

improvements = {}
data_indexes = list(range(2,11)) + list(range(13,21))
for index, data_index in enumerate(data_indexes):
    improvements[name[index]] = sum(data[:, data_index])/len(data[:, data_index])
  
improvements_sorted = {k: v for k, v in sorted(improvements.items(), key=lambda item: item[1], reverse=True)}

for item, value in improvements_sorted.items():
    print(f'average improvement of {item}: {value}')
    print('------------------')
# Out:
# average improvement of udd_x_pe: 0.10358412000868056
# ------------------
# average improvement of cp_pe: 0.09918212890625
# ------------------
# average improvement of xy8_pe: 0.09117363823784723
# ------------------
# average improvement of PE: 0.08923475477430556
# ------------------
# average improvement of xy16_pe: 0.08890177408854169
# ------------------
# average improvement of udd_y_pe: 0.08770141601562502
# ------------------
# average improvement of udd_x_: 0.08648478190104167
# ------------------
# average improvement of cpmg: 0.08013712565104167
# ------------------
# average improvement of cpmg_pe: 0.07966918945312501
# ------------------
# average improvement of xy8: 0.07892930772569445
# ------------------
# average improvement of cp: 0.07883436414930559
# ------------------
# average improvement of xy4_pe: 0.07876722547743056
# ------------------
# average improvement of xy4: 0.07215915256076388
# ------------------
# average improvement of udd_y: 0.06361490885416668
# ...

# %%
pure_dd = ['cp', 'cpmg', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',]
dd_pe = ['cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']


dd_pe_ar = 0
pure_dd_ar = 0

for item, value in improvements.items():
    if item in dd_pe:
        dd_pe_ar += value
    if item in pure_dd:
        pure_dd_ar += value

# %%
(dd_pe_ar - pure_dd_ar) / pure_dd_ar
# Out:
# 0.2654683857083074
