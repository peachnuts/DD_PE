# %%
# import os
# #list the current work dir
# os.getcwd()
# #change the current work dir
# os.chdir('/home/siyuan/Seafile/Thesis/PycharmProjects/DD_PE_paper/')

# %%
from networkx.generators.random_graphs import erdos_renyi_graph
from src.QAOA.QAOA_approximation import generate_three_regular_graph, generate_graph_matrix, create_qaoa_circ, compute_expectation
from scipy.optimize import minimize
import numpy as np

# %%
from qiskit import IBMQ, transpile, Aer
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q-france', group='univ-montpellier', project='default')
backend = provider.get_backend('ibmq_guadalupe')

# %%
from src.tools.DD_insertion import pm_DD_sequences
from qiskit.transpiler import PassManager, InstructionDurations

durations = InstructionDurations.from_backend(backend)
pms = pm_DD_sequences(durations)

# %%
from src.QAOA.QAOA_approximation import get_ansatz_parm

# %%
##Construct 3-regular graphs of different degree
weight_matrices = []
graphs = []
circuits = []

for i in range(4, 13, 2):
    G = generate_three_regular_graph(i)
    res = get_ansatz_parm(G)
    print(res)
    qc = create_qaoa_circ(G, res.x)
    w = generate_graph_matrix(G)
    weight_matrices.append(w)
    graphs.append(G)
    circuits.append(qc)
    print('----------')
# Out:
#      fun: -3.693359375
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 33
#   status: 1
#  success: True
#        x: array([52.12044927, 92.93027933])
# ----------
#      fun: -5.3173828125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 27
#   status: 1
#  success: True
#        x: array([52.14027902, 93.93254817])
# ----------
#      fun: -6.0341796875
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 33
#   status: 1
#  success: True
#        x: array([50.97493708, 91.75939733])
# ----------
#      fun: -9.2822265625
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 32
#   status: 1
#  success: True
#        x: array([51.43942058, 92.4067444 ])
# ----------
#      fun: -9.5009765625
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 35
#   status: 1
#  success: True
#        x: array([52.1257119 , 92.94228148])
# ----------

# %%
## construct randomized graph of different degree
seed = 200
p = 0.5
for i in range(4, 13, 2):
    G = erdos_renyi_graph(i, p, seed)
    res = get_ansatz_parm(G)
    print(res)
    qc = create_qaoa_circ(G, res.x)
    w = generate_graph_matrix(G)
    weight_matrices.append(w)
    graphs.append(G)
    circuits.append(qc)
    print('----------')
# Out:
#      fun: -2.0634765625
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 26
#   status: 1
#  success: True
#        x: array([51.48692938, 93.00036061])
# ----------
#      fun: -6.861328125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 29
#   status: 1
#  success: True
#        x: array([52.08505957, 92.89675027])
# ----------
#      fun: -11.4970703125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 29
#   status: 1
#  success: True
#        x: array([52.07542478, 92.83308516])
# ----------
#      fun: -14.072265625
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 32
#   status: 1
#  success: True
#        x: array([49.79069762, 93.1481553 ])
# ----------
#      fun: -19.521484375
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 35
#   status: 1
#  success: True
#        x: array([52.12625061, 90.93369183])
# ----------

# %%
## add duration of y gates which are used for DD sequences
bconf = backend.configuration()
for i in range(bconf.num_qubits):
    x_duration = durations.get('x', i)
    durations.update(InstructionDurations(
        [('y', i, x_duration)]
        ))

    durations.update(InstructionDurations(
        [('rx', i, x_duration)]
        ))

    durations.update(InstructionDurations(
        [('ry', i, x_duration)]
        ))

# %%
# Template optimisation for RZZ gate and SWAP gate

from qiskit.circuit.library.standard_gates.equivalence_library import StandardEquivalenceLibrary as std_eqlib

# Transpiler passes
from qiskit.transpiler.passes import Collect2qBlocks
from qiskit.transpiler.passes import ConsolidateBlocks
from qiskit.transpiler.passes import Optimize1qGatesDecomposition
from qiskit.transpiler.passes.basis import BasisTranslator, UnrollCustomDefinitions
from qiskit.transpiler.passes.scheduling.calibration_creators import RZXCalibrationBuilderNoEcho
from qiskit.transpiler.passes.optimization.echo_rzx_weyl_decomposition import EchoRZXWeylDecomposition

# %%
inst_map = backend.defaults().instruction_schedule_map
rzx_basis = ['rzx', 'rz', 'x', 'sx']

pm_pulse_efficient = PassManager(
        [
            # Consolidate consecutive two-qubit operations
            Collect2qBlocks(),
            ConsolidateBlocks(basis_gates=['rz', 'sx', 'x', 'rxx']),
            # Rewrite circuit in terms of Cartan-decomposed echoed RZX gates
            EchoRZXWeylDecomposition(backend),
            # Calibrations for RZX gates
            RZXCalibrationBuilderNoEcho(backend),
            # Rewrite in rzx basis
            UnrollCustomDefinitions(std_eqlib, rzx_basis),
            BasisTranslator(std_eqlib, rzx_basis),
            Optimize1qGatesDecomposition(rzx_basis)
        ]
    )

# %%
from src.tools.DD_insertion import translate_circuit_to_basis, rzx_gate_recover

# %%
## combine template optimisation and dd sequences

job_ids = []
jobs = []

for circuit in circuits:
    circuit_list = []
    seed = 1
    transpiled_qc = transpile(circuit, backend=backend, optimization_level=3, seed_transpiler=seed)
    circuit_list.append(transpiled_qc)
    for pm in pms:
        qc_transpile = pm.run(transpiled_qc)
        qc_transpile_base = translate_circuit_to_basis(qc_transpile, bconf)
        circuit_list.append(qc_transpile_base)

    qc_pulse_efficient = pm_pulse_efficient.run(transpiled_qc)
    qc_pulse_efficient_transpile = rzx_gate_recover(qc_pulse_efficient)
    circuit_list.append(qc_pulse_efficient_transpile)

    qc_pulse_calibrations = qc_pulse_efficient.calibrations
    rzx_durations = []

    for key, value in qc_pulse_calibrations.items():
        rzx_duration = tuple()
        for i, elm in value.items():
            rzx_durations.append((elm.name, list(i[0]), elm.duration))
    durations.update(InstructionDurations(rzx_durations))

    pms2 = pm_DD_sequences(durations)

    for pm in pms2:
        qc_transpile = pm.run(qc_pulse_efficient)
        qc_transpile_base = translate_circuit_to_basis(qc_transpile, bconf)
        qc_transpile = rzx_gate_recover(qc_transpile_base)
        circuit_list.append(qc_transpile)

    job = backend.run(circuit_list, shots=8192)
    jobs.append(job)
    job_id = job.job_id()
    print(job_id)
    job_ids.append(job_id)
# Out:
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287661a158b8b76dc943985
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 62876621aaa04c26d003f2b5
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287662aae5524369d46433a
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287663ad1d86b11b6e4d30c
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 628766479c5eed675cc2956b
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287664ce2f2788194fbb434
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 62876653aaa04c1d4903f2b7
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287665faaa04c2c9003f2b8
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 62876670ae55247993464341
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: False
# if applied DD for None: False
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# if applied DD for None: True
# 6287668aaaa04c78e603f2ba

# %%
for job in job_ids:
    print(job)
# Out:
# 6287661a158b8b76dc943985
# 62876621aaa04c26d003f2b5
# 6287662aae5524369d46433a
# 6287663ad1d86b11b6e4d30c
# 628766479c5eed675cc2956b
# 6287664ce2f2788194fbb434
# 62876653aaa04c1d4903f2b7
# 6287665faaa04c2c9003f2b8
# 62876670ae55247993464341
# 6287668aaaa04c78e603f2ba

# %%
from src.QAOA.QAOA_approximation import expectation_result, get_operator
from qiskit.algorithms import NumPyMinimumEigensolver
shots = 8192

# %%
name = ['Original_ideal', 'hahn_X_ideal', 'hahn_Y_ideal', 'cp_ideal', 'cpmg_ideal', 'xy4_ideal', 'xy8_ideal', 'xy16_ideal', 'udd_x_ideal', 'udd_y_ideal', 'KDD_ideal',
        'Original_pe', 'hahn_X_pe', 'hahn_Y_pe', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe', 'KDD_pe']

npme = NumPyMinimumEigensolver()

job_ids = [
'6287661a158b8b76dc943985',
'62876621aaa04c26d003f2b5',
'6287662aae5524369d46433a',
'6287663ad1d86b11b6e4d30c',
'628766479c5eed675cc2956b',
'6287664ce2f2788194fbb434',
'62876653aaa04c1d4903f2b7',
'6287665faaa04c2c9003f2b8',
'62876670ae55247993464341',
'6287668aaaa04c78e603f2ba',
]

graph_name = ['3-regular-4', '3-regular-6', '3-regular-8', '3-regular-10', '3-regular-12',
              'rand-4-0.5', 'rand-6-0.5', 'rand-8-0.5', 'rand-10-0.5', 'rand-12-0.5',]

graph_ratio_results = {}


results_data = {}
for idx, job_id in enumerate(job_ids):
    job = backend.retrieve_job(job_id)
    counts = job.result().get_counts()
    qubit_op, offset, pauli_list = get_operator(weight_matrices[idx])

    approximation_ratios = {}
    exp_val_classical = npme.compute_minimum_eigenvalue(qubit_op).eigenvalue.real
    print(f'--------{graph_name[idx]}----------------')


    approx_ratios =  []
    for i, count in enumerate(counts):
        exp_val_counts = expectation_result(count, shots, pauli_list)
        # print(f'The expectation value of {name[i]} is {exp_val_counts}')

        approximation_ratio = exp_val_counts / exp_val_classical
        approx_ratios.append(approximation_ratio)
        approximation_ratios[name[i]] = approximation_ratio
        print(f'Approximation ratio of {name[i]} is {approximation_ratio}')
    results_data[graph_name[idx]] = approx_ratios
    graph_ratio_results[graph_name[idx]] = approximation_ratios
# Out:
# --------3-regular-4----------------
# Approximation ratio of Original_ideal is 0.3873291015625
# Approximation ratio of hahn_X_ideal is 0.3818359375
# Approximation ratio of hahn_Y_ideal is 0.3843994140625
# Approximation ratio of cp_ideal is 0.410888671875
# Approximation ratio of cpmg_ideal is 0.4180908203125
# Approximation ratio of xy4_ideal is 0.3746337890625
# Approximation ratio of xy8_ideal is 0.44287109375
# Approximation ratio of xy16_ideal is 0.3505859375
# Approximation ratio of udd_x_ideal is 0.4197998046875
# Approximation ratio of udd_y_ideal is 0.405517578125
# Approximation ratio of KDD_ideal is 0.3494873046875
# Approximation ratio of Original_pe is 0.4664306640625
# Approximation ratio of hahn_X_pe is 0.488037109375
# Approximation ratio of hahn_Y_pe is 0.45654296875
# Approximation ratio of cp_pe is 0.444091796875
# Approximation ratio of cpmg_pe is 0.4312744140625
# Approximation ratio of xy4_pe is 0.427978515625
# Approximation ratio of xy8_pe is 0.4554443359375
# Approximation ratio of xy16_pe is 0.429931640625
# Approximation ratio of udd_x_pe is 0.423583984375
# Approximation ratio of udd_y_pe is 0.43212890625
# Approximation ratio of KDD_pe is 0.3741455078125
# --------3-regular-6----------------
# Approximation ratio of Original_ideal is 0.06240234375
# Approximation ratio of hahn_X_ideal is 0.052490234375
# Approximation ratio of hahn_Y_ideal is 0.058837890625
# Approximation ratio of cp_ideal is 0.242724609375
# Approximation ratio of cpmg_ideal is 0.233984375
# Approximation ratio of xy4_ideal is 0.21982421875
# Approximation ratio of xy8_ideal is 0.223388671875
# Approximation ratio of xy16_ideal is 0.210107421875
# Approximation ratio of udd_x_ideal is 0.24267578125
# Approximation ratio of udd_y_ideal is 0.21494140625
# Approximation ratio of KDD_ideal is 0.181103515625
# Approximation ratio of Original_pe is 0.237158203125
# Approximation ratio of hahn_X_pe is 0.24189453125
# Approximation ratio of hahn_Y_pe is 0.233056640625
# Approximation ratio of cp_pe is 0.335498046875
# Approximation ratio of cpmg_pe is 0.335302734375
# Approximation ratio of xy4_pe is 0.3099609375
# Approximation ratio of xy8_pe is 0.293896484375
# Approximation ratio of xy16_pe is 0.280224609375
# Approximation ratio of udd_x_pe is 0.297265625
# Approximation ratio of udd_y_pe is 0.269921875
# Approximation ratio of KDD_pe is 0.246044921875
# --------3-regular-8----------------
# Approximation ratio of Original_ideal is 0.012969970703125
# Approximation ratio of hahn_X_ideal is 0.006683349609375
# Approximation ratio of hahn_Y_ideal is 0.00628662109375
# Approximation ratio of cp_ideal is -0.027557373046875
# Approximation ratio of cpmg_ideal is -0.030670166015625
# Approximation ratio of xy4_ideal is -0.0223388671875
# Approximation ratio of xy8_ideal is -0.030303955078125
# Approximation ratio of xy16_ideal is -0.01593017578125
# Approximation ratio of udd_x_ideal is -0.0341796875
# Approximation ratio of udd_y_ideal is -0.02935791015625
# Approximation ratio of KDD_ideal is -0.019256591796875
# Approximation ratio of Original_pe is -0.01544189453125
# Approximation ratio of hahn_X_pe is -0.01788330078125
# Approximation ratio of hahn_Y_pe is -0.0166015625
# Approximation ratio of cp_pe is -0.0155029296875
# Approximation ratio of cpmg_pe is -0.017669677734375
# Approximation ratio of xy4_pe is -0.01800537109375
# Approximation ratio of xy8_pe is -0.023193359375
# Approximation ratio of xy16_pe is -0.0152587890625
# Approximation ratio of udd_x_pe is -0.03619384765625
# Approximation ratio of udd_y_pe is -0.023712158203125
# Approximation ratio of KDD_pe is -0.037994384765625
# --------3-regular-10----------------
# Approximation ratio of Original_ideal is 0.03810813210227273
# Approximation ratio of hahn_X_ideal is 0.040083451704545456
# Approximation ratio of hahn_Y_ideal is 0.03981711647727273
# Approximation ratio of cp_ideal is 0.14386541193181818
# Approximation ratio of cpmg_ideal is 0.1327237215909091
# Approximation ratio of xy4_ideal is 0.12384588068181818
# Approximation ratio of xy8_ideal is 0.12047230113636363
# Approximation ratio of xy16_ideal is 0.10129616477272728
# Approximation ratio of udd_x_ideal is 0.12493341619318182
# Approximation ratio of udd_y_ideal is 0.09013227982954546
# Approximation ratio of KDD_ideal is 0.08680308948863637
# Approximation ratio of Original_pe is 0.053777521306818184
# Approximation ratio of hahn_X_pe is 0.054154829545454544
# Approximation ratio of hahn_Y_pe is 0.049005681818181816
# Approximation ratio of cp_pe is 0.16417347301136365
# Approximation ratio of cpmg_pe is 0.16923384232954544
# Approximation ratio of xy4_pe is 0.16645951704545456
# Approximation ratio of xy8_pe is 0.15684925426136365
# Approximation ratio of xy16_pe is 0.14972478693181818
# Approximation ratio of udd_x_pe is 0.15977894176136365
# Approximation ratio of udd_y_pe is 0.16417347301136365
# Approximation ratio of KDD_pe is 0.10930841619318182
# --------3-regular-12----------------
# Approximation ratio of Original_ideal is 0.018641880580357144
# Approximation ratio of hahn_X_ideal is 0.012032645089285714
# Approximation ratio of hahn_Y_ideal is 0.0162353515625
# Approximation ratio of cp_ideal is 0.15771484375
# Approximation ratio of cpmg_ideal is 0.14536830357142858
# Approximation ratio of xy4_ideal is 0.13631766183035715
# Approximation ratio of xy8_ideal is 0.13420758928571427
# Approximation ratio of xy16_ideal is 0.058262416294642856
# Approximation ratio of udd_x_ideal is 0.14045061383928573
# Approximation ratio of udd_y_ideal is 0.13009207589285715
# Approximation ratio of KDD_ideal is 0.026349748883928572
# Approximation ratio of Original_pe is 0.015119280133928572
# Approximation ratio of hahn_X_pe is 0.018537248883928572
# Approximation ratio of hahn_Y_pe is 0.020734514508928572
# Approximation ratio of cp_pe is 0.17262486049107142
# Approximation ratio of cpmg_pe is 0.16929408482142858
# Approximation ratio of xy4_pe is 0.18568638392857142
# Approximation ratio of xy8_pe is 0.18312290736607142
# Approximation ratio of xy16_pe is 0.16474260602678573
# Approximation ratio of udd_x_pe is 0.17886788504464285
# Approximation ratio of udd_y_pe is 0.17011369977678573
# Approximation ratio of KDD_pe is 0.15400041852678573
# --------rand-4-0.5----------------
# Approximation ratio of Original_ideal is 0.0413818359375
# Approximation ratio of hahn_X_ideal is 0.0382080078125
# Approximation ratio of hahn_Y_ideal is 0.023193359375
# Approximation ratio of cp_ideal is 0.0313720703125
# Approximation ratio of cpmg_ideal is -0.0106201171875
# Approximation ratio of xy4_ideal is 0.005859375
# Approximation ratio of xy8_ideal is 0.0101318359375
# Approximation ratio of xy16_ideal is 0.0257568359375
# Approximation ratio of udd_x_ideal is 0.0238037109375
# Approximation ratio of udd_y_ideal is 0.005126953125
# Approximation ratio of KDD_ideal is 0.0435791015625
# Approximation ratio of Original_pe is -0.1092529296875
# Approximation ratio of hahn_X_pe is -0.1087646484375
# Approximation ratio of hahn_Y_pe is -0.11474609375
# Approximation ratio of cp_pe is -0.0609130859375
# Approximation ratio of cpmg_pe is -0.0469970703125
# Approximation ratio of xy4_pe is -0.033203125
# Approximation ratio of xy8_pe is -0.08251953125
# Approximation ratio of xy16_pe is -0.0755615234375
# Approximation ratio of udd_x_pe is -0.07080078125
# Approximation ratio of udd_y_pe is -0.09716796875
# Approximation ratio of KDD_pe is -0.070068359375
# --------rand-6-0.5----------------
# Approximation ratio of Original_ideal is 0.0919189453125
# Approximation ratio of hahn_X_ideal is 0.09212239583333333
# Approximation ratio of hahn_Y_ideal is 0.0880126953125
# Approximation ratio of cp_ideal is 0.2088623046875
# Approximation ratio of cpmg_ideal is 0.20841471354166666
# Approximation ratio of xy4_ideal is 0.20654296875
# Approximation ratio of xy8_ideal is 0.1783447265625
# Approximation ratio of xy16_ideal is 0.1341552734375
# Approximation ratio of udd_x_ideal is 0.19632975260416666
# Approximation ratio of udd_y_ideal is 0.16483561197916666
# Approximation ratio of KDD_ideal is 0.13810221354166666
# Approximation ratio of Original_pe is 0.14021809895833334
# Approximation ratio of hahn_X_pe is 0.13631184895833334
# Approximation ratio of hahn_Y_pe is 0.12923177083333334
# Approximation ratio of cp_pe is 0.21516927083333334
# Approximation ratio of cpmg_pe is 0.205810546875
# Approximation ratio of xy4_pe is 0.23148600260416666
# Approximation ratio of xy8_pe is 0.2052001953125
# Approximation ratio of xy16_pe is 0.17333984375
# Approximation ratio of udd_x_pe is 0.21586100260416666
# Approximation ratio of udd_y_pe is 0.20166015625
# Approximation ratio of KDD_pe is 0.181640625
# --------rand-8-0.5----------------
# Approximation ratio of Original_ideal is -0.007459852430555556
# Approximation ratio of hahn_X_ideal is 0.0003255208333333333
# Approximation ratio of hahn_Y_ideal is 0.0011121961805555555
# Approximation ratio of cp_ideal is 0.07977973090277778
# Approximation ratio of cpmg_ideal is 0.062201605902777776
# Approximation ratio of xy4_ideal is 0.0734592013888889
# Approximation ratio of xy8_ideal is 0.071044921875
# Approximation ratio of xy16_ideal is 0.044840494791666664
# Approximation ratio of udd_x_ideal is 0.07381184895833333
# Approximation ratio of udd_y_ideal is 0.040717230902777776
# Approximation ratio of KDD_ideal is 0.027615017361111112
# Approximation ratio of Original_pe is 0.020887586805555556
# Approximation ratio of hahn_X_pe is 0.019775390625
# Approximation ratio of hahn_Y_pe is 0.020941840277777776
# Approximation ratio of cp_pe is 0.10335286458333333
# Approximation ratio of cpmg_pe is 0.0893825954861111
# Approximation ratio of xy4_pe is 0.10107421875
# Approximation ratio of xy8_pe is 0.10411241319444445
# Approximation ratio of xy16_pe is 0.08683268229166667
# Approximation ratio of udd_x_pe is 0.08648003472222222
# Approximation ratio of udd_y_pe is 0.0800509982638889
# Approximation ratio of KDD_pe is 0.0812717013888889
# --------rand-10-0.5----------------
# Approximation ratio of Original_ideal is -0.007790305397727273
# Approximation ratio of hahn_X_ideal is -0.012140447443181818
# Approximation ratio of hahn_Y_ideal is -0.006059126420454545
# Approximation ratio of cp_ideal is 0.018998579545454544
# Approximation ratio of cpmg_ideal is 0.01089754971590909
# Approximation ratio of xy4_ideal is 0.035333806818181816
# Approximation ratio of xy8_ideal is 0.009721235795454546
# Approximation ratio of xy16_ideal is 0.03082830255681818
# Approximation ratio of udd_x_ideal is 0.02239435369318182
# Approximation ratio of udd_y_ideal is 0.02228338068181818
# Approximation ratio of KDD_ideal is 0.017533735795454544
# Approximation ratio of Original_pe is 0.003839666193181818
# Approximation ratio of hahn_X_pe is -0.0034623579545454545
# Approximation ratio of hahn_Y_pe is 0.009011008522727272
# Approximation ratio of cp_pe is 0.011918501420454546
# Approximation ratio of cpmg_pe is 0.022327769886363636
# Approximation ratio of xy4_pe is 0.019975142045454544
# Approximation ratio of xy8_pe is 0.027143998579545456
# Approximation ratio of xy16_pe is 0.023459694602272728
# Approximation ratio of udd_x_pe is 0.04811789772727273
# Approximation ratio of udd_y_pe is 0.027876420454545456
# Approximation ratio of KDD_pe is 0.013006036931818182
# --------rand-12-0.5----------------
# Approximation ratio of Original_ideal is 0.005859375
# Approximation ratio of hahn_X_ideal is 0.0176849365234375
# Approximation ratio of hahn_Y_ideal is 0.0056610107421875
# Approximation ratio of cp_ideal is 0.05401611328125
# Approximation ratio of cpmg_ideal is 0.04644775390625
# Approximation ratio of xy4_ideal is 0.0581817626953125
# Approximation ratio of xy8_ideal is 0.033447265625
# Approximation ratio of xy16_ideal is 0.0016632080078125
# Approximation ratio of udd_x_ideal is 0.060302734375
# Approximation ratio of udd_y_ideal is 0.0135955810546875
# Approximation ratio of KDD_ideal is 0.0067291259765625
# Approximation ratio of Original_pe is 0.0451202392578125
# Approximation ratio of hahn_X_pe is 0.0471343994140625
# Approximation ratio of hahn_Y_pe is 0.0419158935546875
# Approximation ratio of cp_pe is 0.0930328369140625
# Approximation ratio of cpmg_pe is 0.093505859375
# Approximation ratio of xy4_pe is 0.09326171875
# Approximation ratio of xy8_pe is 0.092071533203125
# Approximation ratio of xy16_pe is 0.0794525146484375
# Approximation ratio of udd_x_pe is 0.099578857421875
# Approximation ratio of udd_y_pe is 0.087493896484375
# Approximation ratio of KDD_pe is 0.0665740966796875

# %%
print(results_data)
# Out:
# {'3-regular-4': [0.3873291015625, 0.3818359375, 0.3843994140625, 0.410888671875, 0.4180908203125, 0.3746337890625, 0.44287109375, 0.3505859375, 0.4197998046875, 0.405517578125, 0.3494873046875, 0.4664306640625, 0.488037109375, 0.45654296875, 0.444091796875, 0.4312744140625, 0.427978515625, 0.4554443359375, 0.429931640625, 0.423583984375, 0.43212890625, 0.3741455078125], '3-regular-6': [0.06240234375, 0.052490234375, 0.058837890625, 0.242724609375, 0.233984375, 0.21982421875, 0.223388671875, 0.210107421875, 0.24267578125, 0.21494140625, 0.181103515625, 0.237158203125, 0.24189453125, 0.233056640625, 0.335498046875, 0.335302734375, 0.3099609375, 0.293896484375, 0.280224609375, 0.297265625, 0.269921875, 0.246044921875], '3-regular-8': [0.012969970703125, 0.006683349609375, 0.00628662109375, -0.027557373046875, -0.030670166015625, -0.0223388671875, -0.030303955078125, -0.01593017578125, -0.0341796875, -0.02935791015625, -0.019256591796875, -0.01544189453125, -0.01788330078125, -0.0166015625, -0.0155029296875, -0.017669677734375, -0.01800537109375, -0.023193359375, -0.0152587890625, -0.03619384765625, -0.023712158203125, -0.037994384765625], '3-regular-10': [0.03810813210227273, 0.040083451704545456, 0.03981711647727273, 0.14386541193181818, 0.1327237215909091, 0.12384588068181818, 0.12047230113636363, 0.10129616477272728, 0.12493341619318182, 0.09013227982954546, 0.08680308948863637, 0.053777521306818184, 0.054154829545454544, 0.049005681818181816, 0.16417347301136365, 0.16923384232954544, 0.16645951704545456, 0.15684925426136365, 0.14972478693181818, 0.15977894176136365, 0.16417347301136365, 0.10930841619318182], '3-regular-12': [0.018641880580357144, 0.012032645089285714, 0.0162353515625, 0.15771484375, 0.14536830357142858, 0.13631766183035715, 0.13420758928571427, 0.058262416294642856, 0.14045061383928573, 0.13009207589285715, 0.026349748883928572, 0.015119280133928572, 0.018537248883928572, 0.020734514508928572, 0.17262486049107142, 0.16929408482142858, 0.18568638392857142, 0.18312290736607142, 0.16474260602678573, 0.17886788504464285, 0.17011369977678573, 0.15400041852678573], 'rand-4-0.5': [0.0413818359375, 0.0382080078125, 0.023193359375, 0.0313720703125, -0.0106201171875, 0.005859375, 0.0101318359375, 0.0257568359375, 0.0238037109375, 0.005126953125, 0.0435791015625, -0.1092529296875, -0.1087646484375, -0.11474609375, -0.0609130859375, -0.0469970703125, -0.033203125, -0.08251953125, -0.0755615234375, -0.07080078125, -0.09716796875, -0.070068359375], 'rand-6-0.5': [0.0919189453125, 0.09212239583333333, 0.0880126953125, 0.2088623046875, 0.20841471354166666, 0.20654296875, 0.1783447265625, 0.1341552734375, 0.19632975260416666, 0.16483561197916666, 0.13810221354166666, 0.14021809895833334, 0.13631184895833334, 0.12923177083333334, 0.21516927083333334, 0.205810546875, 0.23148600260416666, 0.2052001953125, 0.17333984375, 0.21586100260416666, 0.20166015625, 0.181640625], 'rand-8-0.5': [-0.007459852430555556, 0.0003255208333333333, 0.0011121961805555555, 0.07977973090277778, 0.062201605902777776, 0.0734592013888889, 0.071044921875, 0.044840494791666664, 0.07381184895833333, 0.040717230902777776, 0.027615017361111112, 0.020887586805555556, 0.019775390625, 0.020941840277777776, 0.10335286458333333, 0.0893825954861111, 0.10107421875, 0.10411241319444445, 0.08683268229166667, 0.08648003472222222, 0.0800509982638889, 0.0812717013888889], 'rand-10-0.5': [-0.007790305397727273, -0.012140447443181818, -0.006059126420454545, 0.018998579545454544, 0.01089754971590909, 0.035333806818181816, 0.009721235795454546, 0.03082830255681818, 0.02239435369318182, 0.02228338068181818, 0.017533735795454544, 0.003839666193181818, -0.0034623579545454545, 0.009011008522727272, 0.011918501420454546, 0.022327769886363636, 0.019975142045454544, 0.027143998579545456, 0.023459694602272728, 0.04811789772727273, 0.027876420454545456, 0.013006036931818182], 'rand-12-0.5': [0.005859375, 0.0176849365234375, 0.0056610107421875, 0.05401611328125, 0.04644775390625, 0.05 ...

# %%
import numpy as np
import matplotlib.pyplot as plt

graph_name = ['3-regular-4', '3-regular-6', '3-regular-8', '3-regular-10', '3-regular-12',
              'rand-4-0.5', 'rand-6-0.5', 'rand-8-0.5', 'rand-10-0.5', 'rand-12-0.5',]

baseline = []

# name = ['Baseline', 'cp', 'cpmgl', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',
#         'PE', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']

data = []
for name in graph_name:
    result_data = results_data[name]
    baseline.append(result_data[0])
    ratio = [i - result_data[0] for i in result_data[1:]]
    data.append(ratio)


data = np.array(data)
# hahn = data[:, 0]
cp = data[:, 2]
cpmg = data[:, 3]
xy4 = data[:, 4]
xy8 = data[:, 5]
xy16 = data[:, 6]
udd_X = data[:, 7]
udd_Y = data[:, 8]
kdd = data[:, 9]

pe = data[:, 10]
# hahn_to = data[:, 10]
cp_pe = data[:, 13]
cpmg_pe = data[:, 14]
xy4_pe = data[:, 15]
xy8_pe = data[:, 16]
xy16_pe = data[:, 17]
udd_X_pe = data[:, 18]
udd_Y_pe = data[:, 19]
kdd_pe = data[:, 20]

graph_name_x = ['3-reg-4', '3-reg-6', '3-reg-8', '3-reg-10', '3-reg-12',
              'rand-4-0.5', 'rand-6-0.5', 'rand-8-0.5', 'rand-10-0.5', 'rand-12-0.5',]
x_ticks = graph_name_x
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])

# plt.plot(X, hahn, linestyle='--', marker='o', color='g', label='hahn')
plt.scatter(X, cp, s=50, marker='o', color='orange', label='cp')
plt.scatter(X, cpmg, s=50, marker='.', color='b', label='cpmg')
plt.scatter(X, xy4, s=50, marker='^', color='r', label='xy4')
plt.scatter(X, xy8, s=50, marker='X', color='g', label='xy8')
plt.scatter(X, xy16, s=50, marker='h', color='c', label='xy16')
plt.scatter(X, udd_X, s=50, marker='d', color='y', label='udd_x')
plt.scatter(X, udd_Y, s=50, marker='+', color='k', label='udd_y')
plt.scatter(X, kdd, s=50, marker='*', color='m', label='kdd')


plt.axhline(0, color='tab:brown', lw=2)

plt.legend(loc='best', fontsize=14)
# ax.set_title('Relative approximate ratio with only DD sequences on ibmq_guadalupe', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks)
ax.set_ylabel('Relative approximation ratio', fontsize=16)
plt.savefig('Relat_AR_guadalupe_DD_0520_TQE.pdf', bbox_inches='tight', pad_inches=0)

# %%
graph_name = ['3-regular-4', '3-regular-6', '3-regular-8', '3-regular-10', '3-regular-12',
              'rand-4-0.5', 'rand-6-0.5', 'rand-8-0.5', 'rand-10-0.5', 'rand-12-0.5',]

baseline = []

# name = ['Baseline', 'cp', 'cpmgl', 'xy4', 'xy8', 'xy16', 'udd_x_', 'udd_y', 'kdd',
#         'PE', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe','kdd_pe']

data = []
for name in graph_name:
    result_data = results_data[name]
    baseline.append(result_data[0])
    ratio = [i - result_data[0] for i in result_data[1:]]
    data.append(ratio)


data = np.array(data)
# hahn = data[:, 0]
cp = data[:, 2]
cpmg = data[:, 3]
xy4 = data[:, 4]
xy8 = data[:, 5]
xy16 = data[:, 6]
udd_X = data[:, 7]
udd_Y = data[:, 8]
kdd = data[:, 9]

pe = data[:, 10]
# hahn_to = data[:, 10]
cp_pe = data[:, 13]
cpmg_pe = data[:, 14]
xy4_pe = data[:, 15]
xy8_pe = data[:, 16]
xy16_pe = data[:, 17]
udd_X_pe = data[:, 18]
udd_Y_pe = data[:, 19]
kdd_pe = data[:, 20]

x_ticks = graph_name_x
X = np.arange(len(x_ticks))

from matplotlib.pyplot import figure
fig = figure(num=None, figsize=(8, 6), dpi=600, facecolor='w', edgecolor='k')
ax = fig.add_axes([0,0,1,1])
# plt.scatter(X, cp, linestyle='--', marker='o', color='orange', label='cp')
# plt.scatter(X, cpmg, linestyle='--', marker='.', color='b', label='cpmg')
# plt.scatter(X, xy4, linestyle='--', marker='^', color='r', label='xy4')
# plt.scatter(X, xy8, linestyle='--', marker='X', color='g', label='xy8')
# plt.scatter(X, xy16, linestyle='--', marker='h', color='c', label='xy16')
# plt.scatter(X, udd_X, linestyle='--', marker='d', color='y', label='udd_x')
# plt.scatter(X, udd_Y, linestyle='--', marker='+', color='k', label='udd_y')
# plt.scatter(X, kdd, linestyle='--', marker='*', color='m', label='kdd')


plt.scatter(X, pe, s=50, marker='P', color='tab:purple', label='pe')
# plt.plot(X, hahn_to, linestyle='--', marker='s', color='m', label='hahn_to')
plt.scatter(X, cp_pe, s=50, marker='o', color='orange', label='cp_pe')
plt.scatter(X, cpmg_pe, s=50, marker='.', color='b', label='cpmg_pe')
plt.scatter(X, xy4_pe, s=50, marker='^', color='r', label='xy4_pe')
plt.scatter(X, xy8_pe, s=50, marker='X', color='g', label='xy8_pe')
plt.scatter(X, xy16_pe, s=50, marker='h', color='c', label='xy16_pe')
plt.scatter(X, udd_X_pe, s=50, marker='d', color='y', label='udd_x_pe')
plt.scatter(X, udd_Y_pe, s=50, marker='+', color='k', label='udd_y_pe')
plt.scatter(X, kdd_pe, s=50, marker='*', color='m', label='kdd_pe')

plt.axhline(0, color='tab:brown', lw=2)

plt.legend(loc='best', fontsize=14)
# ax.set_title('Relative approximate ratio with DD sequences+pulse efficient on ibmq_guadalupe', fontsize=18)
ax.set_xticks(X)
ax.set_xticklabels(x_ticks)
ax.set_ylabel('Relative approximation ratio', fontsize=16)

plt.savefig('Relat_AR_guadalupe_DD_pe_0520_TQE.pdf', bbox_inches='tight', pad_inches=0)

# %%
name = ['Original_ideal', 'hahn_X_ideal', 'hahn_Y_ideal', 'cp_ideal', 'cpmg_ideal', 'xy4_ideal', 'xy8_ideal', 'xy16_ideal', 'udd_x_ideal', 'udd_y_ideal', 'KDD_ideal',
        'Original_pe', 'hahn_X_pe', 'hahn_Y_pe', 'cp_pe', 'cpmg_pe', 'xy4_pe', 'xy8_pe', 'xy16_pe', 'udd_x_pe', 'udd_y_pe', 'KDD_pe']
for i in range(2,21):
    print(name[i+1], data[:,i])
    print('average of improvement:',sum(data[:,i])/len(data[:,i]))
    print('----')
# Out:
# cp_ideal [ 0.02355957  0.18032227 -0.04052734  0.10575728  0.13907296 -0.01000977
#   0.11694336  0.08723958  0.02678888  0.04815674]
# average of improvement: 0.06773035354944534
# ----
# cpmg_ideal [ 0.03076172  0.17158203 -0.04364014  0.09461559  0.12672642 -0.05200195
#   0.11649577  0.06966146  0.01868786  0.04058838]
# average of improvement: 0.057347713321834415
# ----
# xy4_ideal [-0.01269531  0.15742187 -0.03530884  0.08573775  0.11767578 -0.03552246
#   0.11462402  0.08091905  0.04312411  0.05232239]
# average of improvement: 0.05682983706695864
# ----
# xy8_ideal [ 0.05554199  0.16098633 -0.04327393  0.08236417  0.11556571 -0.03125
#   0.08642578  0.07850477  0.01751154  0.02758789]
# average of improvement: 0.05499642596444354
# ----
# xy16_ideal [-0.03674316  0.14770508 -0.02890015  0.06318803  0.03962054 -0.015625
#   0.04223633  0.05230035  0.03861861 -0.00419617]
# average of improvement: 0.029820445227244547
# ----
# udd_x_ideal [ 0.0324707   0.18027344 -0.04714966  0.08682528  0.12180873 -0.01757812
#   0.10441081  0.0812717   0.03018466  0.05444336]
# average of improvement: 0.06269609019181772
# ----
# udd_y_ideal [ 0.01818848  0.15253906 -0.04232788  0.05202415  0.1114502  -0.03625488
#   0.07291667  0.04817708  0.03007369  0.00773621]
# average of improvement: 0.04145227605646307
# ----
# KDD_ideal [-0.0378418   0.11870117 -0.03222656  0.04869496  0.00770787  0.00219727
#   0.04618327  0.03507487  0.02532404  0.00086975]
# average of improvement: 0.02146848340055127
# ----
# Original_pe [ 0.07910156  0.17475586 -0.02841187  0.01566939 -0.0035226  -0.15063477
#   0.04829915  0.02834744  0.01162997  0.03926086]
# average of improvement: 0.02144950085044079
# ----
# hahn_X_pe [ 1.00708008e-01  1.79492187e-01 -3.08532715e-02  1.60466974e-02
#  -1.04631696e-04 -1.50146484e-01  4.43929036e-02  2.72352431e-02
#   4.32794744e-03  4.12750244e-02]
# average of improvement: 0.023237362375851146
# ----
# hahn_Y_pe [ 0.06921387  0.1706543  -0.02957153  0.01089755  0.00209263 -0.15612793
#   0.03731283  0.02840169  0.01680131  0.03605652]
# average of improvement: 0.018573123552066424
# ----
# cp_pe [ 0.0567627   0.2730957  -0.0284729   0.12606534  0.15398298 -0.10229492
#   0.12325033  0.11081272  0.01970881  0.08717346]
# average of improvement: 0.08200842082586467
# ----
# cpmg_pe [ 0.04394531  0.27290039 -0.03063965  0.13112571  0.1506522  -0.08837891
#   0.1138916   0.09684245  0.03011808  0.08764648]
# average of improvement: 0.08081036720441018
# ----
# xy4_pe [ 0.04064941  0.24755859 -0.03097534  0.12835138  0.1670445  -0.07458496
#   0.13956706  0.10853407  0.02776545  0.08740234]
# average of improvement: 0.0841312513034925
# ----
# xy8_pe [ 0.06811523  0.23149414 -0.03616333  0.11874112  0.16448103 -0.12390137
#   0.11328125  0.11157227  0.0349343   0.08621216]
# average of improvement: 0.07687668044845779
# ----
# xy16_pe [ 0.04260254  0.21782227 -0.02822876  0.11161665  0.14610073 -0.11694336
#   0.0814209   0.09429253  0.03125     0.07359314]
# average of improvement: 0.06535266386310087
# ----
# udd_x_pe [ 0.03625488  0.23486328 -0.04916382  0.12167081  0.160226   -0.11218262
#   0.12394206  0.09393989  0.0559082   0.09371948]
# average of improvement: 0.07591781726303211
# ----
# udd_y_pe [ 0.0447998   0.20751953 -0.03668213  0.12606534  0.15147182 -0.1385498
#   0.10974121  0.08751085  0.03566673  0.08163452]
# average of improvement: 0.06691778714178617
# ----
# KDD_pe [-0.01318359  0.18364258 -0.05096436  0.07120028  0.13535854 -0.1114502
#   0.08972168  0.08873155  0.02079634  0.06071472]
# average of improvement: 0.0474567553147265
# ----

# %%
np.max(data)
# Out:
# 0.27309570312500003

# %%
#only DD max value
np.max(data[:,2:10])
# Out:
# 0.180322265625

# %%
(0.27309570312500003-0.1802734375)/0.1802734375
# Out:
# 0.5148970747562299
